# %%
from agents.fairy.FairyState import FairyState
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from agents.fairy.FairyState import FairyState
#
# ModuleNotFoundError: No module named 'agents'
