# %%
lines = [
            "[방금 돌아온 기억 - 반드시 먼저 언급해야 함]",
            "",
            "- 이 기억이 방금 떠올랐습니다.",
            "- 페르소나에 맞는 말투로 '~에 대한 기억이 돌아왔어' 같은 반응을 하세요.",
            "- 플레이어의 질문에 답하기 전에 먼저 기억이 돌아온 것을 언급하세요.",
        ]
print("\n".join(lines)+"\n")
# Out:
# [방금 돌아온 기억 - 반드시 먼저 언급해야 함]
#
# - 이 기억이 방금 떠올랐습니다.
# - 페르소나에 맞는 말투로 '~에 대한 기억이 돌아왔어' 같은 반응을 하세요.
# - 플레이어의 질문에 답하기 전에 먼저 기억이 돌아온 것을 언급하세요.
