# %%
import sys
import os

ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(ROOT)

# %%
from core.common import get_project_root, get_data_path, get_cur_timestamp, read_json, write_json

# %%
get_project_root()
# Out:
# PosixPath('/Users/seobi/PythonProjects/ProjectML')

# %%
get_cur_timestamp()
# Out:
# 1763950777

# %%
read_json(get_data_path() / "test.json")
# Out:
# {'메롱': '메롱'}

# %%
write_json(get_data_path() /"test2.json", {"바보":"바보"})

# %%
from core.common import find_files
find_files(get_data_path(), patterns=("*.json",))
find_files(get_project_root() / "src"/"data" , patterns=("*.json",))
# Out:
# [PosixPath('/Users/seobi/PythonProjects/ProjectML/src/data/test.json')]
